# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from StringIO import StringIO
import pymc3 as pm, theano.tensor as tt

# %%
#####
year_start = 2010
year_end   = 2015
#####

###### DATA PREPARATION ################
df = []
for season in range(year_start,year_end):
  ssn_str = str(season)[-2:]+str(season+1)[-2:]
  results_tmp = pd.read_csv('football-data-website/EPL_'+ssn_str+'.csv')
  results_tmp['Season']=pd.Series(int(ssn_str),index=results_tmp.index)
  if len(df)>0:
    df = df.append(results_tmp, ignore_index=True)
  else:
    df = results_tmp

# %%
teams = df.HomeTeam.unique()
teams = pd.DataFrame(teams, columns=['team'])
teams['i'] = teams.index

df = pd.merge(df, teams, left_on='HomeTeam', right_on='team', how='left')
df = df.rename(columns = {'i': 'i_home'}).drop('team', 1)
df = pd.merge(df, teams, left_on='AwayTeam', right_on='team', how='left')
df = df.rename(columns = {'i': 'i_away'}).drop('team', 1)

observed_home_goals = df.FTHG.values
observed_away_goals = df.FTAG.values

home_team = df.i_home.values
away_team = df.i_away.values

num_teams = len(df.i_home.drop_duplicates())
num_games = len(home_team)

g = df.groupby('i_away')
att_starting_points =  np.log(g.FTHG.mean())
g = df.groupby('i_home')
def_starting_points = -np.log(g.FTAG.mean())

# %%
(teams['team'][teams['i']==0].values)[0]
# Out:
# 'Aston Villa'

# %%
model = pm.Model()
with pm.Model() as model:
    # global model parameters
    home        = pm.Normal('home',      0, .0001)
    tau_att     = pm.Gamma('tau_att',   .1, .1)
    tau_def     = pm.Gamma('tau_def',   .1, .1)
    intercept   = pm.Normal('intercept', 0, .0001)
    
    # team-specific model parameters
    atts_star   = pm.Normal("atts_star", 
                           mu   =0,
                           tau  =tau_att, 
                           shape=num_teams)
    defs_star   = pm.Normal("defs_star", 
                           mu   =0,
                           tau  =tau_def,  
                           shape=num_teams) 
 
    atts        = pm.Deterministic('atts', atts_star - tt.mean(atts_star))
    defs        = pm.Deterministic('defs', defs_star - tt.mean(defs_star))
    home_theta  = tt.exp(intercept + home + atts[away_team] + defs[home_team])
    away_theta  = tt.exp(intercept        + atts[away_team] + defs[home_team])
    
    # likelihood of observed data
    home_points = pm.Poisson('home_points', mu=home_theta, observed=observed_home_goals)
    away_points = pm.Poisson('away_points', mu=away_theta, observed=observed_away_goals)

# %%
with model:
    start = pm.find_MAP()
    step = pm.NUTS(state=start)
    trace = pm.sample(2000, step, start=start, progressbar=True)
    pm.traceplot(trace)
# Out:
#  [                  0%                  ] 11 of 2000 complete in 0.5 sec
#  [                  1%                  ] 22 of 2000 complete in 1.1 sec
#  [                  1%                  ] 30 of 2000 complete in 1.6 sec
#  [                  2%                  ] 45 of 2000 complete in 2.2 sec
#  [-                 2%                  ] 57 of 2000 complete in 2.7 sec
#  [-                 3%                  ] 61 of 2000 complete in 3.3 sec
#  [-                 3%                  ] 67 of 2000 complete in 3.8 sec
#  [-                 3%                  ] 78 of 2000 complete in 4.3 sec
#  [-                 4%                  ] 88 of 2000 complete in 4.8 sec
#  [-                 4%                  ] 96 of 2000 complete in 5.3 sec
#  [--                5%                  ] 107 of 2000 complete in 5.9 sec
#  [--                6%                  ] 121 of 2000 complete in 6.4 sec
#  [--                6%                  ] 130 of 2000 complete in 6.9 sec
#  [--                7%                  ] 142 of 2000 complete in 7.4 sec
#  [--                7%                  ] 147 of 2000 complete in 7.9 sec
#  [---               7%                  ] 158 of 2000 complete in 8.5 sec
#  [---               8%                  ] 169 of 2000 complete in 9.0 sec
#  [---               9%                  ] 181 of 2000 complete in 9.5 sec
#  [---               9%                  ] 193 of 2000 complete in 10.0 sec
#  [---              10%                  ] 206 of 2000 complete in 10.6 sec
#  [----             11%                  ] 222 of 2000 complete in 11.1 sec
#  [----             11%                  ] 233 of 2000 complete in 11.6 sec
#  [----             12%                  ] 246 of 2000 complete in 12.1 sec
#  [----             12%                  ] 257 of 2000 complete in 12.6 sec
#  [-----            13%                  ] 270 of 2000 complete in 13.2 sec
#  [-----            14%                  ] 283 of 2000 complete in 13.7 sec
#  [-----            14%                  ] 296 of 2000 complete in 14.2 sec
#  [-----            15%                  ] 309 of 2000 complete in 14.7 sec
#  [------           16%                  ] 322 of 2000 complete in 15.2 sec
#  [------           16%                  ] 335 of 2000 complete in 15.7 sec
#  [------           17%                  ] 346 of 2000 complete in 16.3 sec
#  [------           17%                  ] 359 of 2000 complete in 16.8 sec
#  [-------          18%                  ] 372 of 2000 complete in 17.3 sec
#  [-------          19%                  ] 385 of 2000 complete in 17.9 sec
#  [-------          19%                  ] 398 of 2000 complete in 18.4 sec
#  [-------          20%                  ] 409 of 2000 complete in 18.9 sec
#  [--------         21%                  ] 423 of 2000 complete in 19.4 sec
#  [--------         21%                  ] 436 of 2000 complete in 19.9 sec
#  [--------         22%                  ] 448 of 2000 complete in 20.4 sec
#  [--------         23%                  ] 462 of 2000 complete in 21.0 sec
#  [--------         23%                  ] 468 of 2000 complete in 21.6 sec
#  [---------        24%                  ] 480 of 2000 complete in 22.1 sec
#  [---------        24%                  ] 489 of 2000 complete in 22.6 sec
#  [---------        25%                  ] 500 of 2000 complete in 23.2 sec
#  [---------        25%                  ] 512 of 2000 complete in 23.7 sec
#  [---------        26%                  ] 523 of 2000 complete in 24.2 sec
#  [----------       26%                  ] 537 of 2000 complete in 24.8 sec
#  [----------       27%                  ] 547 of 2000 complete in 25.3 sec
#  [----------       28%                  ] 561 of 2000 complete in 25.8 sec
#  [----------       28%                  ] 574 of 2000 complete in 26.3 sec
#  [-----------      29%                  ] 586 of 2000 complete in 26.9 sec
#  [-----------      30%                  ] 602 of 2000 complete in 27.4 sec
#  [-----------      30%                  ] 616 of 2000 complete in 28.0 sec
#  [-----------      31%                  ] 625 of 2000 complete in 28.5 sec
#  [------------     31%                  ] 637 of 2000 complete in 29.0 sec
#  [------------     32%                  ] 649 of 2000 complete in 29.5 sec
#  [------------     33%                  ] 661 of 2000 complete in 30.0 sec
#  [------------     33%                  ] 673 of 2000 complete in 30.5 sec
#  [-------------    34%                  ] 686 of 2000 complete in 31.1 sec
#  [-------------    35%                  ] 700 of 2000 complete in 31.6 sec
#  [-------------    35%                  ] 711 of 2000 complete in 32.1 sec
#  [-------------    36%                  ] 723 of 2000 complete in 32.6 sec
#  [-------------    36%                  ] 735 of 2000 complete in 33.1 sec
#  [--------------   37%                  ] 744 of 2000 complete in 33.7 sec
#  [--------------   37%                  ] 757 of 2000 complete in 34.2 sec
#  [--------------   38%                  ] 770 of 2000 complete in 34.7 sec
#  [--------------   39%                  ] 782 of 2000 complete in 35.2 sec
#  [---------------  39%                  ] 795 of 2000 complete in 35.8 sec
#  [---------------  40%                  ] 808 of 2000 complete in 36.3 sec
#  [---------------  40%                  ] 819 of 2000 complete in 36.8 sec
#  [---------------  41%                  ] 831 of 2000 complete in 37.3 sec
#  [---------------- 42%                  ] 843 of 2000 complete in 37.8 sec
#  [---------------- 42%                  ] 855 of 2000 complete in 38.4 sec
#  [---------------- 43%                  ] 868 of 2000 complete in 38.9 sec
#  [---------------- 44%                  ] 880 of 2000 complete in 39.4 sec
#  [---------------- 44%                  ] 893 of 2000 complete in 39.9 sec
#  [-----------------45%                  ] 906 of 2000 complete in 40.5 sec
#  [-----------------45%                  ] 919 of 2000 complete in 41.0 sec
#  [-----------------46%                  ] 933 of 2000 complete in 41.5 sec
#  [-----------------47%                  ] 945 of 2000 complete in 42.0 sec
#  [-----------------47%                  ] 957 of 2000 complete in 42.5 sec
#  [-----------------48%                  ] 970 of 2000 complete in 43.0 sec
#  [-----------------49%                  ] 983 of 2000 complete in 43.6 sec
#  [-----------------49%                  ] 989 of 2000 complete in 44.1 sec
#  [-----------------50%                  ] 1002 of 2000 complete in 44.6 sec
#  [-----------------50%                  ] 1015 of 2000 complete in 45.2 sec
#  [-----------------51%                  ] 1029 of 2000 complete in 45.7 sec
#  [-----------------52%                  ] 1042 of 2000 complete in 46.2 sec
#  [-----------------52%                  ] 1056 of 2000 complete in 46.7 sec
#  [-----------------53%                  ] 1068 of 2000 complete in 47.2 sec
#  [-----------------54%                  ] 1081 of 2000 complete in 47.8 sec
#  [-----------------54%                  ] 1093 of 2000 complete in 48.3 sec
#  [-----------------55%                  ] 1105 of 2000 complete in 48.8 sec
#  [-----------------55%-                 ] 1118 of 2000 complete in 49.3 sec
#  [-----------------56%-                 ] 1131 of 2000 complete in 49.9 sec
#  [-----------------57%-                 ] 1144 of 2000 complete in 50.4 sec
#  [-----------------57%-                 ] 1157 of 2000 complete in 50.9 sec
#  [-----------------58%--                ] 1170 of 2000 complete in 51.4 sec
#  [-----------------59%--                ] 1183 of 2000 complete in 52.0 sec
#  [-----------------59%--                ] 1196 of 2000 complete in 52.5 sec
#  [-----------------60%--                ] 1209 of 2000 complete in 53.0 sec
#  [-----------------61%---               ] 1222 of 2000 complete in 53.5 sec
#  [-----------------61%---               ] 1234 of 2000 complete in 54.0 sec
#  [-----------------62%---               ] 1247 of 2000 complete in 54.6 sec
#  [-----------------63%---               ] 1261 of 2000 complete in 55.1 sec
#  [-----------------63%----              ] 1270 of 2000 complete in 55.6 sec
#  [-----------------64%----              ] 1286 of 2000 complete in 56.2 sec
#  [-----------------64%----              ] 1299 of 2000 complete in 56.7 sec
#  [-----------------65%----              ] 1311 of 2000 complete in 57.2 sec
#  [-----------------66%-----             ] 1324 of 2000 complete in 57.7 sec
#  [-----------------66%-----             ] 1336 of 2000 complete in 58.2 sec
#  [-----------------67%-----             ] 1350 of 2000 complete in 58.7 sec
#  [-----------------68%-----             ] 1362 of 2000 complete in 59.3 sec
#  [-----------------68%------            ] 1374 of 2000 complete in 59.8 sec
#  [-----------------69%------            ] 1386 of 2000 complete in 60.3 sec
#  [-----------------69%------            ] 1399 of 2000 complete in 60.8 sec
#  [-----------------70%------            ] 1412 of 2000 complete in 61.3 sec
#  [-----------------71%-------           ] 1426 of 2000 complete in 61.8 sec
#  [-----------------72%-------           ] 1443 of 2000 complete in 62.4 sec
#  [-----------------72%-------           ] 1455 of 2000 complete in 62.9 sec
#  [-----------------73%-------           ] 1468 of 2000 complete in 63.4 sec
#  [-----------------74%--------          ] 1481 of 2000 complete in 63.9 sec
#  [-----------------74%--------          ] 1498 of 2000 complete in 64.4 sec
#  [-----------------75%--------          ] 1510 of 2000 complete in 64.9 sec
#  [-----------------76%--------          ] 1523 of 2000 complete in 65.4 sec
#  [-----------------76%---------         ] 1536 of 2000 complete in 66.0 sec
#  [-----------------77%---------         ] 1549 of 2000 complete in 66.5 sec
#  [-----------------78%---------         ] 1561 of 2000 complete in 67.0 sec
#  [-----------------78%---------         ] 1574 of 2000 complete in 67.5 sec
#  [-----------------79%----------        ] 1587 of 2000 complete in 68.0 sec
#  [-----------------80%----------        ] 1600 of 2000 complete in 68.6 sec
#  [-----------------80%----------        ] 1613 of 2000 complete in 69.1 sec
#  [-----------------81%----------        ] 1626 of 2000 complete in 69.6 sec
#  [-----------------81%-----------       ] 1638 of 2000 complete in 70.1 sec
#  [-----------------82%-----------       ] 1652 of 2000 complete in 70.7 sec
#  [-----------------83%-----------       ] 1664 of 2000 complete in 71.2 sec
#  [-----------------83%-----------       ] 1677 of 2000 complete in 71.7 sec
#  [-----------------84%------------      ] 1689 of 2000 complete in 72.2 sec
#  [-----------------85%------------      ] 1702 of 2000 complete in 72.7 sec
#  [-----------------85%------------      ] 1716 of 2000 complete in 73.2 sec
#  [-----------------86%------------      ] 1724 of 2000 complete in 73.8 sec
#  [-----------------86%------------      ] 1736 of 2000 complete in 74.3 sec
#  [-----------------87%-------------     ] 1748 of 2000 complete in 74.8 sec
#  [-----------------88%-------------     ] 1761 of 2000 complete in 75.3 sec
#  [-----------------88%-------------     ] 1774 of 2000 complete in 75.8 sec
#  [-----------------89%--------------    ] 1790 of 2000 complete in 76.4 sec
#  [-----------------90%--------------    ] 1800 of 2000 complete in 76.9 sec
#  [-----------------90%--------------    ] 1813 of 2000 complete in 77.4 sec
#  [-----------------91%--------------    ] 1822 of 2000 complete in 78.0 sec
#  [-----------------91%--------------    ] 1830 of 2000 complete in 78.5 sec
#  [-----------------92%--------------    ] 1842 of 2000 complete in 79.0 sec
#  [-----------------92%---------------   ] 1854 of 2000 complete in 79.5 sec
#  [-----------------93%---------------   ] 1866 of 2000 complete in 80.0 sec
#  [-----------------94%---------------   ] 1880 of 2000 complete in 80.5 sec
#  [-----------------94%---------------   ] 1888 of 2000 complete in 81.1 sec
#  [-----------------94%----------------  ] 1897 of 2000 complete in 81.6 sec
#  [-----------------95%----------------  ] 1909 of 2000 complete in 82.1 sec
#  [-----------------96%----------------  ] 1922 of 2000 complete in 82.6 sec
#  [-----------------96%----------------  ] 1934 of 2000 complete in 83.1 sec
#  [-----------------97%----------------  ] 1947 of 2000 complete in 83.6 sec
#  [-----------------97%----------------- ] 1959 of 2000 complete in 84.2 sec
#  [-----------------98%----------------- ] 1972 of 2000 complete in 84.7 sec
#  [-----------------99%----------------- ] 1985 of 2000 complete in 85.2 sec
#  [-----------------99%----------------- ] 1998 of 2000 complete in 85.8 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 85.9 sec

# %%
atts_tr = np.array(trace["atts_star"])
defs_tr = np.array(trace["defs_star"])

# %%
plt.rcParams['figure.figsize'] = (14.0, 12.0)
for i in range(num_teams):
    axs = plt.subplot(int(np.ceil(num_teams/4.)), 4 ,i)
    plt.hist(atts_tr[:,i], histtype='stepfilled', bins=30, alpha=0.5,
         color="#7A68A6", normed=True)
    plt.hist(defs_tr[:,i], histtype='stepfilled', bins=30, alpha=0.5,
         color="#A60628", normed=True)
    plt.ylabel((teams['team'][teams['i']==i].values)[0])
#    plt.legend(loc="upper right")
